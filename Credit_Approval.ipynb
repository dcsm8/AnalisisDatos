# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Set a few plotting defaults
# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['font.size'] = 18
plt.rcParams['patch.edgecolor'] = 'k'

# %%
df = pd.read_csv('data.csv')
df.columns = ('X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'Y')
df.head()
# Out:
#   X1     X2     X3 X4 X5 X6 X7    X8 X9 X10  X11 X12 X13    X14  X15  Y
# 0  a  58.67  4.460  u  g  q  h  3.04  t   t    6   f   g  00043  560  +
# 1  a  24.50  0.500  u  g  q  h  1.50  t   f    0   f   g  00280  824  +
# 2  b  27.83  1.540  u  g  w  v  3.75  t   t    5   t   g  00100    3  +
# 3  b  20.17  5.625  u  g  w  v  1.71  t   f    0   f   s  00120    0  +
# 4  b  32.08  4.000  u  g  m  v  2.50  t   f    0   t   g  00360    0  +

# %%
df.tail()
# Out:
#     X1     X2      X3 X4 X5  X6  X7    X8 X9 X10  X11 X12 X13    X14  X15  Y
# 684  b  21.08  10.085  y  p   e   h  1.25  f   f    0   f   g  00260    0  -
# 685  a  22.67   0.750  u  g   c   v  2.00  f   t    2   t   g  00200  394  -
# 686  a  25.25  13.500  y  p  ff  ff  2.00  f   t    1   t   g  00200    1  -
# 687  b  17.92   0.205  u  g  aa   v  0.04  f   f    0   f   g  00280  750  -
# 688  b  35.00   3.375  u  g   c   h  8.29  f   f    0   t   g  00000    0  -

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 16 columns):
# X1     689 non-null object
# X2     689 non-null object
# X3     689 non-null float64
# X4     689 non-null object
# X5     689 non-null object
# X6     689 non-null object
# X7     689 non-null object
# X8     689 non-null float64
# X9     689 non-null object
# X10    689 non-null object
# X11    689 non-null int64
# X12    689 non-null object
# X13    689 non-null object
# X14    689 non-null object
# X15    689 non-null int64
# Y      689 non-null object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 86.2+ KB

# %%
for column in df:
    print(df[column].value_counts(dropna=False).head())
# Out:
# b    467
# a    210
# ?     12
# Name: X1, dtype: int64
# ?        12
# 22.67     9
# 20.42     7
# 20.67     6
# 18.83     6
# Name: X2, dtype: int64
# 1.50    21
# 2.50    19
# 3.00    19
# 0.00    18
# 0.75    16
# Name: X3, dtype: int64
# u    518
# y    163
# ?      6
# l      2
# Name: X4, dtype: int64
# g     518
# p     163
# ?       6
# gg      2
# Name: X5, dtype: int64
# c     137
# q      78
# w      63
# i      59
# aa     54
# Name: X6, dtype: int64
# v     398
# h     138
# bb     59
# ff     57
# ?       9
# Name: X7, dtype: int64
# 0.000    70
# 0.250    35
# 0.040    33
# 1.000    31
# 0.125    30
# Name: X8, dtype: int64
# t    360
# f    329
# Name: X9, dtype: int64
# f    395
# t    294
# Name: X10, dtype: int64
# 0    395
# 1     70
# 2     45
# 3     28
# 6     23
# Name: X11, dtype: int64
# f    373
# t    316
# Name: X12, dtype: int64
# g    624
# s     57
# p      8
# Name: X13, dtype: int64
# 00000    132
# 00200     35
# 00120     35
# 00160     34
# ...

# %%
df.describe()
# Out:
#                X3          X8         X11            X15
# count  689.000000  689.000000  689.000000     689.000000
# mean     4.765631    2.224819    2.402032    1018.862119
# std      4.978470    3.348739    4.866180    5213.743149
# min      0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.165000    0.000000       0.000000
# 50%      2.750000    1.000000    0.000000       5.000000
# 75%      7.250000    2.625000    3.000000     396.000000
# max     28.000000   28.500000   67.000000  100000.000000

# %% [markdown]
# ## Manejar datos nulos

# %% [markdown]
# ### Los datos nulos en el dataset se encuentran como signos de interrogación (?)

# %%
df.isnull().sum()
# Out:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
# X6     0
# X7     0
# X8     0
# X9     0
# X10    0
# X11    0
# X12    0
# X13    0
# X14    0
# X15    0
# Y      0
# dtype: int64

# %%
df = df.replace('?', np.nan)

# %%
df.isnull().sum()
# Out:
# X1     12
# X2     12
# X3      0
# X4      6
# X5      6
# X6      9
# X7      9
# X8      0
# X9      0
# X10     0
# X11     0
# X12     0
# X13     0
# X14    13
# X15     0
# Y       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 16 columns):
# X1     677 non-null object
# X2     677 non-null object
# X3     689 non-null float64
# X4     683 non-null object
# X5     683 non-null object
# X6     680 non-null object
# X7     680 non-null object
# X8     689 non-null float64
# X9     689 non-null object
# X10    689 non-null object
# X11    689 non-null int64
# X12    689 non-null object
# X13    689 non-null object
# X14    676 non-null object
# X15    689 non-null int64
# Y      689 non-null object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 86.2+ KB

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ### Feature Encoding

# %%
for column in df:
    print(df[column].value_counts(dropna=False).head())
# Out:
# b      467
# a      210
# NaN     12
# Name: X1, dtype: int64
# NaN      12
# 22.67     9
# 20.42     7
# 20.67     6
# 22.50     6
# Name: X2, dtype: int64
# 1.50    21
# 2.50    19
# 3.00    19
# 0.00    18
# 0.75    16
# Name: X3, dtype: int64
# u      518
# y      163
# NaN      6
# l        2
# Name: X4, dtype: int64
# g      518
# p      163
# NaN      6
# gg       2
# Name: X5, dtype: int64
# c     137
# q      78
# w      63
# i      59
# aa     54
# Name: X6, dtype: int64
# v      398
# h      138
# bb      59
# ff      57
# NaN      9
# Name: X7, dtype: int64
# 0.000    70
# 0.250    35
# 0.040    33
# 1.000    31
# 0.125    30
# Name: X8, dtype: int64
# t    360
# f    329
# Name: X9, dtype: int64
# f    395
# t    294
# Name: X10, dtype: int64
# 0    395
# 1     70
# 2     45
# 3     28
# 6     23
# Name: X11, dtype: int64
# f    373
# t    316
# Name: X12, dtype: int64
# g    624
# s     57
# p      8
# Name: X13, dtype: int64
# 00000    132
# 00120     35
# ...

# %%
# Iterate over each column of cc_apps
for col in df:
    # Check if the column is of object type
    if df[col].dtypes == 'object':
        # Impute with the most frequent value
        df = df.fillna(df[col].value_counts().index[0])

# Count the number of NaNs in the dataset and print the counts to verify
for column in df:
    print(df[column].value_counts(dropna=False).head())
# Out:
# b    479
# a    210
# Name: X1, dtype: int64
# b        12
# 22.67     9
# 20.42     7
# 20.67     6
# 18.83     6
# Name: X2, dtype: int64
# 1.50    21
# 2.50    19
# 3.00    19
# 0.00    18
# 0.75    16
# Name: X3, dtype: int64
# u    518
# y    163
# b      6
# l      2
# Name: X4, dtype: int64
# g     518
# p     163
# b       6
# gg      2
# Name: X5, dtype: int64
# c     137
# q      78
# w      63
# i      59
# aa     54
# Name: X6, dtype: int64
# v     398
# h     138
# bb     59
# ff     57
# b       9
# Name: X7, dtype: int64
# 0.000    70
# 0.250    35
# 0.040    33
# 1.000    31
# 0.125    30
# Name: X8, dtype: int64
# t    360
# f    329
# Name: X9, dtype: int64
# f    395
# t    294
# Name: X10, dtype: int64
# 0    395
# 1     70
# 2     45
# 3     28
# 6     23
# Name: X11, dtype: int64
# f    373
# t    316
# Name: X12, dtype: int64
# g    624
# s     57
# p      8
# Name: X13, dtype: int64
# 00000    132
# 00120     35
# 00200     35
# 00160     34
# 00080     30
# ...

# %%
# Import LabelEncoder
from sklearn.preprocessing import LabelEncoder

# Instantiate LabelEncoder
le = LabelEncoder()

# Iterate over all the values of each column and extract their dtypes
for col in df:
    # Compare if the dtype is object
    if df[col].dtypes == 'object' and col is not 'Y':
        # Use LabelEncoder to do the numeric transformation
        le.fit(df[col].unique())
        df[col] = le.transform(df[col])

def encode_target(Y):
    if Y == '-':
        return 0
    return 1
df.Y = df.Y.apply(encode_target)

# %% [markdown]
# ## Data Visualization

# %%
df.head()
# Out:
#    X1   X2     X3  X4  X5  X6  X7    X8  X9  X10  X11  X12  X13  X14  X15  Y
# 0   0  327  4.460   2   1  11   4  3.04   1    1    6    0    0   11  560  1
# 1   0   89  0.500   2   1  11   4  1.50   1    0    0    0    0   95  824  1
# 2   1  125  1.540   2   1  13   8  3.75   1    1    5    1    0   31    3  1
# 3   1   43  5.625   2   1  13   8  1.71   1    0    0    0    2   37    0  1
# 4   1  167  4.000   2   1  10   8  2.50   1    0    0    1    0  114    0  1

# %%
df.describe()
# Out:
#                X1          X2          X3          X4          X5          X6  \
# count  689.000000  689.000000  689.000000  689.000000  689.000000  689.000000
# mean     0.695210  150.081277    4.765631    2.216255    1.467344    6.597968
# std      0.460653   95.829226    4.978470    0.477362    0.860566    4.408573
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   71.000000    1.000000    2.000000    1.000000    2.000000
# 50%      1.000000  133.000000    2.750000    2.000000    1.000000    6.000000
# 75%      1.000000  225.000000    7.250000    2.000000    1.000000   11.000000
# max      1.000000  348.000000   28.000000    3.000000    3.000000   14.000000
#
#                X7          X8          X9         X10         X11         X12  \
# count  689.000000  689.000000  689.000000  689.000000  689.000000  689.000000
# mean     5.991292    2.224819    0.522496    0.426705    2.402032    0.458636
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df.Y.value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Credito aprobado')
ax[0].set_ylabel('')
sns.countplot('Y',data=df,ax=ax[1])
ax[1].set_title('Credito aprobado')
plt.show()

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Correlation Matrix with Heatmap

# %%
sns.heatmap(df.corr(),linewidths=.5,annot=True,cmap='RdYlGn')
fig=plt.gcf()
fig.set_size_inches(15,8)
plt.show()

# %% [markdown]
# ### Univariate Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X = df.iloc[:,0:15]
y = df.iloc[:,-1]


#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#    Specs          Score
# 14   X15  569482.499414
# 10   X11    1124.997978
# 1     X2     749.129873
# 7     X8     362.376448
# 13   X14     245.195174
# 8     X9     170.547562
# 2     X3     155.060520
# 9    X10      82.597852
# 5     X6      33.197196
# 12   X13      12.217596

# %% [markdown]
# ### Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

X=df.drop('Y',axis=1)
y=df['Y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

logreg = LogisticRegression()

logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

print("Efectividad modelo regresion logistica: ", logreg.score(X_test, y_test))

print(confusion_matrix(y_test, y_pred))
# Out:
# Efectividad modelo regresion logistica:  0.868421052631579
# [[105  23]
#  [  7  93]]
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
